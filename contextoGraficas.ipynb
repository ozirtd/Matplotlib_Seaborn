# %% [markdown]
# <a href="https://colab.research.google.com/github/ozirtd/Matplotlib_Seaborn/blob/main/contextoGraficas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,5,11)
y = np.sin(x)

# %%
fig, axes = plt.subplots(1,2, figsize=(10,5)) #obtener lienzos
axes[0].plot(x,y,label="$sin(x)$")
axes[0].set_title('Relacion X - Y')
axes[0].set_xlabel('X')
axes[0].set_ylabel('Y')
axes[0].legend()

axes[1].plot(y,x)
axes[1].set_title('Relacion Y - X')
axes[1].set_xlabel('Y')
axes[1].set_ylabel('X')
# Out:
# Text(0, 0.5, 'X')

# %%
plt.plot(x,y,label='sin(x)')
plt.title('Este es un titulo')
plt.xlabel('x')
plt.xlabel('y')
plt.legend(loc='lower left', bbox_to_anchor=(1,0.1))
